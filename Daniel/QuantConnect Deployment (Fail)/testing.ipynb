# %%
#import sys
#print(sys.executable)
#import lean
# Out:
# c:\Users\narut\OneDrive\Documents\Finance Bros\Trading-for-Dummies-test-\.venv\Scripts\python.exe

# %%
from AlgorithmImports import *
from quantconnect.research import QuantBook

qb = QuantBook()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from AlgorithmImports import *
# ----> 2 from quantconnect.research import QuantBook
#       4 qb = QuantBook()
#
# ModuleNotFoundError: No module named 'quantconnect'
